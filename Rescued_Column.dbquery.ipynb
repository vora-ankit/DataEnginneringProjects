-- %%
SELECT *
FROM  read_files(
  '/Volumes/parquettestcatalog/default/parquettestvolume/CSVTestDirectory/Test_Emissions_Data_2023_2.csv',
  FORMAT => 'csv',
  HEADER => TRUE,
  schema => '''state_id int,
  county_name string,
  population bigint''',
  rescueddatacolumn => 'rescued_data'
);
